# %% [markdown]
# # Test bed for loading database with SAdLSA data and visualizing the results
#
# This notebook is a sandbox for loading SAdLSA data into the pandas dataframe, querying those dataframes, and then visualizing the alignment results.

# %% [markdown]
# ### PREAMBLE

# %%
cd /home/rbdavid/Scripts/git/structural_DLFA/parsers
# Out:
# /home/rbdavid/Scripts/git/structural_DLFA/parsers

# %%
import sadlsa_parsers

# %%
cd /home/rbdavid/Scripts/git/structural_DLFA/visualizers
# Out:
# /home/rbdavid/Scripts/git/structural_DLFA/visualizers

# %%
import visualize_sadlsa_results
from pathlib import Path

# %% [markdown]
# ### CHANGE THESE TO POINT TO YOUR OWN DATA FILES

# %%
data_dir = '/home/rbdavid/Projects/ornl_DLFA/temp_sadlsa_results/'
working_dir = '/home/rbdavid/Projects/ornl_DLFA/temp_sadlsa_results/temp/'

# %%
mkdir /home/rbdavid/Projects/ornl_DLFA/temp_sadlsa_results/temp/

# %% [markdown]
# ### SANDBOX

# %%
score_file = data_dir + '/WP_164928147.1_sco.dat.gz'
alignment_file = data_dir + '/WP_010940344.1_aln.dat.gz'

# %%
score_df = sadlsa_parsers.parse_sadlsa_score_file(score_file,count=20)

# %%
score_df
# Out:
#            protein  seqname  alnlen range1  tmscore1 range2  tmscore2  \
# 0   WP_164928147.1   5G3Q_A      49   3-51    0.3542   1-57    0.2628
# 1   WP_164928147.1   1DP3_A      44   8-51    0.3476   1-51    0.3418
# 2   WP_164928147.1   4QPO_A      44   8-51    0.3472   1-51    0.3445
# 3   WP_164928147.1   2D8U_A      51   1-51    0.3277  10-61    0.3168
# 4   WP_164928147.1   3OMY_B      45   7-51    0.3262   1-50    0.3254
# 5   WP_164928147.1   3OMY_A      45   7-51    0.3262   1-50    0.3254
# 6   WP_164928147.1   5Z7G_D      43   4-48    0.3175   1-43    0.3184
# 7   WP_164928147.1   5Z7L_D      43   4-48    0.3175   1-43    0.3184
# 8   WP_164928147.1   2KJF_A      50   1-51    0.3136   3-52    0.3014
# 9   WP_164928147.1   5U96_A      45   1-49    0.3124   8-52    0.3121
# 10  WP_164928147.1   5U96_H      45   1-49    0.3124   8-52    0.3121
# 11  WP_164928147.1   5TVO_B      50   2-51    0.3065   1-53    0.3000
# 12  WP_164928147.1   2FZ0_A      47   5-51    0.3027   1-58    0.1746
# 13  WP_164928147.1   6KTO_D      50   2-51    0.3020   1-53    0.2987
# 14  WP_164928147.1   5UAE_B      47   1-51    0.2947  13-59    0.2913
# 15  WP_164928147.1   5UAE_A      47   1-51    0.2947  13-59    0.2913
# 16  WP_164928147.1   6TB3_L      48   1-51    0.2943  15-62    0.2783
# 17  WP_164928147.1  5TBW_d8      48   1-51    0.2943  15-62    0.2783
# 18  WP_164928147.1   4X0N_B      42   7-51    0.2933   1-42    0.2941
# 19  WP_164928147.1   4H4N_A      51   1-51    0.2912  10-67    0.2777
#
#     alnscore  seq_id
# 0     473.20    18.4
# 1     503.39    15.9
# 2     503.61    20.5
# 3     575.45    11.8
# 4     511.72    13.3
# 5     511.72    13.3
# 6     494.08     4.7
# 7     494.08     4.7
# 8     529.80     8.0
# 9     514.38     6.7
# 10    514.38     6.7
# 11    531.44     8.0
# 12    463.74    10.6
# 13    521.95     8.0
# 14    527.45     6.4
# 15    527.45     6.4
# 16    497.20    10.4
# 17    497.20    10.4
# 18    470.13     2.4
# 19    530.88     9.8

# %%
visualize_sadlsa_results.query_score_df(score_df)
# Out:
# array([['5G3Q_A', 0.3542, 473.2, 49, 18.4],
#        ['1DP3_A', 0.3476, 503.39, 44, 15.9],
#        ['4QPO_A', 0.3472, 503.61, 44, 20.5],
#        ['2D8U_A', 0.3277, 575.45, 51, 11.8],
#        ['3OMY_B', 0.3262, 511.72, 45, 13.3],
#        ['3OMY_A', 0.3262, 511.72, 45, 13.3],
#        ['5Z7G_D', 0.3175, 494.08, 43, 4.7],
#        ['5Z7L_D', 0.3175, 494.08, 43, 4.7],
#        ['2KJF_A', 0.3136, 529.8, 50, 8.0],
#        ['5U96_A', 0.3124, 514.38, 45, 6.7],
#        ['5U96_H', 0.3124, 514.38, 45, 6.7],
#        ['5TVO_B', 0.3065, 531.44, 50, 8.0],
#        ['2FZ0_A', 0.3027, 463.74, 47, 10.6],
#        ['6KTO_D', 0.302, 521.95, 50, 8.0],
#        ['5UAE_B', 0.2947, 527.45, 47, 6.4],
#        ['5UAE_A', 0.2947, 527.45, 47, 6.4],
#        ['6TB3_L', 0.2943, 497.2, 48, 10.4],
#        ['5TBW_d8', 0.2943, 497.2, 48, 10.4],
#        ['4X0N_B', 0.2933, 470.13, 42, 2.4],
#        ['4H4N_A', 0.2912, 530.88, 51, 9.8]], dtype=object)

# %%
align_df = sadlsa_parsers.parse_sadlsa_aln_file(str(alignment_file),count=20)

# %%
align_df.head()
# Out:
#           protein  Aln_num Prot_ID  naln   score    tms1    tms2   sid  Ind  \
# 0  WP_010940344.1        1  2HW4_A    81  1044.8  0.8026  0.4908  11.1    1
# 1  WP_010940344.1        1  2HW4_A    81  1044.8  0.8026  0.4908  11.1    2
# 2  WP_010940344.1        1  2HW4_A    81  1044.8  0.8026  0.4908  11.1    3
# 3  WP_010940344.1        1  2HW4_A    81  1044.8  0.8026  0.4908  11.1    4
# 4  WP_010940344.1        1  2HW4_A    81  1044.8  0.8026  0.4908  11.1    5
#
#    Res1 AA1  Res2 AA2  MeanDist  Bin  Prob<3  Prob<5  Prob<8  S
# 0     1   M    39   F     2.165    1   0.878   0.950   0.988  0
# 1     2   K    40   K     1.660    1   0.956   0.985   0.996  1
# 2     3   Y    41   Y     1.431    1   0.977   0.992   0.998  1
# 3     4   I    42   V     1.398    1   0.978   0.990   0.998  0
# 4     5   I    43   L     1.403    1   0.977   0.990   0.998  0

# %%
align_df.tail()
# Out:
#              protein  Aln_num Prot_ID  naln  score    tms1    tms2   sid  Ind  \
# 1576  WP_010940344.1       20  5X8P_U    75  873.9  0.5681  0.4257  14.7   71
# 1577  WP_010940344.1       20  5X8P_U    75  873.9  0.5681  0.4257  14.7   72
# 1578  WP_010940344.1       20  5X8P_U    75  873.9  0.5681  0.4257  14.7   73
# 1579  WP_010940344.1       20  5X8P_U    75  873.9  0.5681  0.4257  14.7   74
# 1580  WP_010940344.1       20  5X8P_U    75  873.9  0.5681  0.4257  14.7   75
#
#       Res1 AA1  Res2 AA2  MeanDist  Bin  Prob<3  Prob<5  Prob<8  S
# 1576    77   R   118   F     6.817    2   0.322   0.500   0.718  0
# 1577    78   D   119   P     8.193    2   0.234   0.399   0.622  0
# 1578    79   T   120   G     9.639   21   0.177   0.316   0.517  0
# 1579    80   G   121   G     9.982   21   0.155   0.288   0.493  1
# 1580    81   V   122   N    10.451   21   0.144   0.265   0.455  0

# %%
visualize_sadlsa_results.query_alignment_df(align_df,'5G3Q_A','Prob<3')
# Out:
# array([], shape=(0, 2), dtype=float64)

# %%
metric_str = 'Prob<3'
colorbar_label = 'Prob < 3 $\AA$'
for pdb in visualize_sadlsa_results.query_score_df(score_df)[:,0]:
    print(pdb)
    pdbid = pdb[:-2]
    chainid = pdb[-1]
    temp = visualize_sadlsa_results.query_alignment_df(align_df, pdb,metric_str)
    structure_file = visualize_sadlsa_results.grab_structure(pdbid,working_dir=working_dir)
    visualize_sadlsa_results.edit_pdb(structure_file,chainid,temp,metric_str)
    #visualize_sadlsa_results.create_vmd_vis_state(working_dir+'%s_%s.vmd'%(pdb,metric_str),
    #                 working_dir+'%s_%s_colorbar.png'%(pdb,metric_str),
    #                 working_dir+'%s_%s.pdb'%(pdb,metric_str),1.0,'blue',colorbar_label=colorbar_label)
# Out:
# 5G3Q_A
# 1DP3_A
# /home/rbdavid/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# 4QPO_A
# 2D8U_A
# /home/rbdavid/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# 3OMY_B
# 3OMY_A
# 5Z7G_D
# 5Z7L_D
# 2KJF_A
# /home/rbdavid/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# 5U96_A
# 5U96_H
# 5TVO_B
# 2FZ0_A
# /home/rbdavid/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# 6KTO_D
# 5UAE_B
# 5UAE_A
# 6TB3_L
# https://files.rcsb.org/view/6TB3.cif returns an error. No pdb file written out.
# Grabbing the cif file.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-67b1bdc32e38> in <module>
#       7     temp = visualize_sadlsa_results.query_alignment_df(align_df, pdb,metric_str)
#       8     structure_file = visualize_sadlsa_results.grab_structure(pdbid,working_dir=working_dir)
# ----> 9     visualize_sadlsa_results.edit_pdb(structure_file,chainid,temp,metric_str)
#      10     #visualize_sadlsa_results.create_vmd_vis_state(working_dir+'%s_%s.vmd'%(pdb,metric_str),
#      11     #                 working_dir+'%s_%s_colorbar.png'%(pdb,metric_str),
#
# ~/Scripts/git/structural_DLFA/visualizers/visualize_sadlsa_results.py in edit_pdb(target_structure, chainID, metric_data, metric_type, string_type, default_value)
#      99     with warnings.catch_warnings():
#     100         #warnings.simplefilter('ignore',UserWarning)
# --> 101         u = MDAnalysis.Universe(target_structure)
#     102         # creating the atom selection groups for the structure
#     103         prot = u.select_atoms('protein and chainID %s'%(chainID))
#
# ~/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/core/universe.py in __init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     334         if not isinstance(topology, Topology) and not topology is None:
#     335             self.filename = _check_file_like(topology)
# --> 336             topology = _topology_from_file_like(self.filename,
#     337                                                 topology_format=topology_format,
#     338                                                 **kwargs)
#
# ~/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/core/universe.py in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     116 def _topology_from_file_like(topology_file, topology_format=None,
#     117                              **kwargs):
# --> 118     parser = get_parser_for(topology_file, format=topology_format)
#     119
#     120     try:
#
# ~/Apps/Python-3.8.2/lib/python3.8/site-packages/MDAnalysis/core/_get_readers.py in get_parser_for(filename, format)
#     254                 "   https://github.com/MDAnalysis/mdanalysis/issues".format(
#     255                     format, _PARSERS.keys()))
# --> 256             raise ValueError(errmsg) from None
#     257         else:
#     258             return _PARSERS['MINIMAL']
#
# ValueError: 'CIF' isn't a valid topology format, nor a coordinate format
#    from which a topology can be minimally inferred.
#    You can use 'Universe(topology, ..., topology_format=FORMAT)'
#    to explicitly specify the format and
#    override automatic detection. Known FORMATs are:
#    dict_keys(['PSF', 'TOP', 'PRMTOP', 'PARM7', 'PDB', 'ENT', 'XPDB', 'PQR', 'GRO', 'CRD', 'PDBQT', 'DMS', 'TPR', 'MOL2', 'DATA', 'LAMMPSDUMP', 'XYZ', 'TXYZ', 'ARC', 'GMS', 'CONFIG', 'HISTORY', 'XML', 'MMTF', 'GSD', 'MINIMAL', 'ITP', 'IN', 'FHIAIMS', 'PARMED', 'RDKIT', 'OPENMMTOPOLOGY', 'OPENMMAPP'])
#    See https://docs.mdanalysis.org/documentation_pages/topology/init.html#supported-topology-formats
#    For missing formats, raise an issue at
#    https://github.com/MDAnalysis/mdanalysis/issues
